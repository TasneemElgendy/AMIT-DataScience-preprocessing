# %%
import pandas as pd

dft = pd.read_csv("Titanic_DS.csv")

# %%
dft.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
dft.describe(include="all")
# Out:
#         PassengerId    Survived      Pclass                             Name  \
# count    899.000000  899.000000  899.000000                              899
# unique          NaN         NaN         NaN                              891
# top             NaN         NaN         NaN  Sandstrom, Miss. Marguerite Rut
# freq            NaN         NaN         NaN                                2
# mean     442.133482    0.384872    2.311457                              NaN
# std      259.437704    0.486836    0.835456                              NaN
# min        1.000000    0.000000    1.000000                              NaN
# 25%      217.500000    0.000000    2.000000                              NaN
# 50%      442.000000    0.000000    3.000000                              NaN
# 75%      666.500000    1.000000    3.000000                              NaN
# max      891.000000    1.000000    3.000000                              NaN
#
# ...

# %%
dft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 899 entries, 0 to 898
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  899 non-null    int64
#  1   Survived     899 non-null    int64
#  2   Pclass       899 non-null    int64
#  3   Name         899 non-null    object
#  4   Sex          899 non-null    object
#  5   Age          722 non-null    float64
#  6   SibSp        899 non-null    int64
#  7   Parch        899 non-null    int64
#  8   Ticket       899 non-null    object
#  9   Fare         899 non-null    float64
#  10  Cabin        206 non-null    object
#  11  Embarked     897 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 84.4+ KB

# %%
dft.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
obj_columns_t = dft.select_dtypes(["object"]).columns
obj_columns_t
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
num_cols_t = dft.select_dtypes(["int" , "float"]).columns
num_cols_t
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
dft.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          693
# Embarked         2
# dtype: int64

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------- __________________________________________________________________

# %%
dfa = pd.read_csv("AB_NYC_2019.csv")
dfa
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48905  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48906  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48907  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48908  36485609               43rd St. Time Square-cozy single bed  30985759
# 48909  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
dfa.head(10)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6  5121                                   BlissArtsSpace!     7356
# 7  5178                  Large Furnished Room Near B'way      8967
# 8  3831                   Cozy Entire Floor of Brownstone     4869
# 9  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0         John            Brooklyn          Kensington  40.64749  -73.97237
# ...

# %%
dfa.describe(include="all")
# Out:
#                   id            name       host_id host_name  \
# count   4.891000e+04           48894  4.891000e+04     48889
# unique           NaN           47905           NaN     11452
# top              NaN  Hillside Hotel           NaN   Michael
# freq             NaN              18           NaN       417
# mean    1.901131e+07             NaN  6.759927e+07       NaN
# std     1.098647e+07             NaN  7.860783e+07       NaN
# min     2.539000e+03             NaN  2.438000e+03       NaN
# 25%     9.464182e+06             NaN  7.806633e+06       NaN
# 50%     1.967483e+07             NaN  3.077540e+07       NaN
# 75%     2.915046e+07             NaN  1.074344e+08       NaN
# max     3.648724e+07             NaN  2.743213e+08       NaN
#
#        neighbourhood_group neighbourhood      latitude     longitude  \
# count                48910         48910  48910.000000  48910.000000
# unique                   5           221           NaN           NaN
# ...

# %%
dfa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48910 entries, 0 to 48909
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48910 non-null  int64
#  1   name                            48894 non-null  object
#  2   host_id                         48910 non-null  int64
#  3   host_name                       48889 non-null  object
#  4   neighbourhood_group             48910 non-null  object
#  5   neighbourhood                   48910 non-null  object
#  6   latitude                        48910 non-null  float64
#  7   longitude                       48910 non-null  float64
#  8   room_type                       48910 non-null  object
#  9   price                           48910 non-null  int64
#  10  minimum_nights                  48910 non-null  int64
#  11  number_of_reviews               48910 non-null  int64
# ...

# %%
obj_columns_a = dfa.select_dtypes(["object"]).columns
obj_columns_a
# Out:
# Index(['name', 'host_name', 'neighbourhood_group', 'neighbourhood',
#        'room_type', 'last_review'],
#       dtype='object')

# %%
num_cols_a = dfa.select_dtypes(["int", "float"]).columns
num_cols_a
# Out:
# Index(['id', 'host_id', 'latitude', 'longitude', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
dfa.drop_duplicates(inplace = True)
dfa
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48905  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48906  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48907  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48908  36485609               43rd St. Time Square-cozy single bed  30985759
# 48909  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
try :
    dfa.drop('last_review', axis=1, inplace=True)
except Exception as e:
        print (f"Error : {e}")

# %%
num_of_miss = dfa.isna().sum()
num_of_miss
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# day_col                           10052
# month_col                         10052
# year_col                          10052
# dtype: int64

# %%
dfa['day_col'].fillna(dfa['day_col'].shift(1) + 1, inplace=True)
dfa['month_col'].fillna(method='ffill', inplace=True)
dfa['year_col'].fillna(method='ffill', inplace=True)

# %%
num_of_miss = dfa.isna().sum()
num_of_miss
# Out:
# id                                    0
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# day_col                            3200
# month_col                             0
# year_col                              0
# dtype: int64

# %%
dfa['day_col'].fillna(method='ffill', inplace=True)

# %%
num_of_miss = dfa.isna().sum()
num_of_miss
# Out:
# id                                    0
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# day_col                               0
# month_col                             0
# year_col                              0
# dtype: int64

# %%
def out(col):
    threshold = 1.5 
    Q1 = dfa[col].quantile(0.25)
    Q3 = dfa[col].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - threshold * IQR
    upper_bound = Q3 + threshold * IQR

    outliers = (dfa[col] < lower_bound) | (dfa[col] > upper_bound)

    col_outliers = dfa[col][outliers]
    num_outliers = price_outliers.shape[0]
    print(f"The {col} column has {num_outliers} outlier(s):\n{col_outliers}\n")

# %%
out("price")
# Out:
# The price column has 2972 outlier(s):
# 76       375
# 100      800
# 118      500
# 129      350
# 136      400
#         ...
# 48773    350
# 48848    475
# 48854    800
# 48857    350
# 48871    345
# Name: price, Length: 2972, dtype: int64

# %%
out("reviews_per_month")
# Out:
# The reviews_per_month column has 2972 outlier(s):
# 486      6.70
# 549      6.62
# 568      7.14
# 1118     5.27
# 1140     5.12
#          ...
# 47723    6.00
# 47863    5.00
# 47982    6.00
# 48046    7.00
# 48243    5.00
# Name: reviews_per_month, Length: 1793, dtype: float64

# %%
x = dfa["reviews_per_month"].median()
dfa["reviews_per_month"].fillna(x, inplace = True)

# %%
dfa
# Out:
#              id   host_id      host_name neighbourhood_group  \
# 0          2539      2787           John            Brooklyn
# 1          2595      2845       Jennifer           Manhattan
# 2          3647      4632      Elisabeth           Manhattan
# 3          3831      4869    LisaRoxanne            Brooklyn
# 4          5022      7192          Laura           Manhattan
# ...         ...       ...            ...                 ...
# 48905  36484665   8232441        Sabrina            Brooklyn
# 48906  36485057   6570630        Marisol            Brooklyn
# 48907  36485431  23492952  Ilgar & Aysel           Manhattan
# 48908  36485609  30985759            Taz           Manhattan
# 48909  36487245  68119814     Christophe           Manhattan
#
#             neighbourhood  latitude  longitude        room_type  price  \
# 0              Kensington  40.64749  -73.97237     Private room    149
# 1                 Midtown  40.75362  -73.98377  Entire home/apt    225
# ...

# %%
dfa.isna().sum()
# Out:
# id                                 0
# host_id                            0
# host_name                         21
# neighbourhood_group                0
# neighbourhood                      0
# latitude                           0
# longitude                          0
# room_type                          0
# price                              0
# minimum_nights                     0
# number_of_reviews                  0
# reviews_per_month                  0
# calculated_host_listings_count     0
# availability_365                   0
# day_col                            0
# month_col                          0
# year_col                           0
# dtype: int64

# %%
dfa["host_name"].fillna("host_name",inplace = True)

# %%
dfa.isna().sum()
# Out:
# id                                0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# day_col                           0
# month_col                         0
# year_col                          0
# dtype: int64

# %%
try :
    dfa.drop('name', axis=1, inplace=True)
except Exception as e:
        print (f"Error : {e}")
# Out:
# Error : "['name'] not found in axis"

# %%
total_records = dfa.shape[0]


for col , val in num_of_miss.items():
    percentage = (val / total_records) * 100
    print (f"column {col} :{percentage:.2f}%")
# Out:
# column id :0.00%
# column name :0.03%
# column host_id :0.00%
# column host_name :0.04%
# column neighbourhood_group :0.00%
# column neighbourhood :0.00%
# column latitude :0.00%
# column longitude :0.00%
# column room_type :0.00%
# column price :0.00%
# column minimum_nights :0.00%
# column number_of_reviews :0.00%
# column last_review :20.55%
# column reviews_per_month :20.55%
# column calculated_host_listings_count :0.00%
# column availability_365 :0.00%
# column day_col :20.55%
# column month_col :20.55%
# column year_col :20.55%

# %%
dfa.corr(numeric_only=True)
# Out:
#                                       id   host_id  latitude  longitude  \
# id                              1.000000  0.588410 -0.003198   0.091000
# host_id                         0.588410  1.000000  0.020183   0.127105
# latitude                       -0.003198  0.020183  1.000000   0.084764
# longitude                       0.091000  0.127105  0.084764   1.000000
# price                           0.010727  0.015363  0.033934  -0.150005
# minimum_nights                 -0.013351 -0.017427  0.024788  -0.062727
# number_of_reviews              -0.320184 -0.140440 -0.015265   0.058392
# reviews_per_month               0.291413  0.296211 -0.010245   0.145823
# calculated_host_listings_count  0.133309  0.154981  0.019507  -0.114695
# availability_365                0.085439  0.203462 -0.011003   0.082672
# day_col                        -0.018002 -0.014715  0.000167  -0.013487
# month_col                      -0.051798 -0.030509 -0.002168   0.000784
# ...

# %%
num_of_miss
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# day_col                           10052
# month_col                         10052
# year_col                          10052
# dtype: int64

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------- __________________________________________________________________

# %%
dfa["last_review"] = pd.to_datetime(dfa["last_review"])
dfa["last_review"]
# Out:
# 0       2018-10-19
# 1       2019-05-21
# 2              NaT
# 3       2019-07-05
# 4       2018-11-19
#            ...
# 48905          NaT
# 48906          NaT
# 48907          NaT
# 48908          NaT
# 48909          NaT
# Name: last_review, Length: 48910, dtype: datetime64[ns]

# %%
day_col = dfa["last_review"].dt.day
day_col
# Out:
# 0        19.0
# 1        21.0
# 2         NaN
# 3         5.0
# 4        19.0
#          ...
# 48905     NaN
# 48906     NaN
# 48907     NaN
# 48908     NaN
# 48909     NaN
# Name: last_review, Length: 48910, dtype: float64

# %%
month_col = dfa["last_review"].dt.month
month_col
# Out:
# 0        10.0
# 1         5.0
# 2         NaN
# 3         7.0
# 4        11.0
#          ...
# 48905     NaN
# 48906     NaN
# 48907     NaN
# 48908     NaN
# 48909     NaN
# Name: last_review, Length: 48910, dtype: float64

# %%
year_col = dfa["last_review"].dt.year
year_col
# Out:
# 0        2018.0
# 1        2019.0
# 2           NaN
# 3        2019.0
# 4        2018.0
#           ...
# 48905       NaN
# 48906       NaN
# 48907       NaN
# 48908       NaN
# 48909       NaN
# Name: last_review, Length: 48910, dtype: float64

# %%
dfa["day_col"] = day_col

# %%
dfa["month_col"] = month_col

# %%
dfa["year_col"] = year_col

# %%
dfa
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48905  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48906  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48907  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48908  36485609               43rd St. Time Square-cozy single bed  30985759
# 48909  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
max_price_y = dfa[["price","year_col"]].groupby("year_col").max()
max_price_y
# Out:
#           price
# year_col
# 2011.0      299
# 2012.0      700
# 2013.0     5000
# 2014.0      800
# 2015.0     9999
# 2016.0    10000
# 2017.0    10000
# 2018.0     8500
# 2019.0     7500

# %%
max_price_r = dfa[["price","room_type"]].groupby("room_type").max()
max_price_r
# Out:
#                  price
# room_type
# Entire home/apt  10000
# Private room     10000
# Shared room       1800
